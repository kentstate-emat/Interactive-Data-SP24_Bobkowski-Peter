# %% [markdown]
# ### **seaborn Challenge**

# %% [markdown]
# ### **Group 1 Demo**

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set_theme(style = "darkgrid")

# %%
diabetes = pd.read_csv("Diabetes.csv")

# %%
diabetes
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0              2  115.863387      56.410731      24.336736   94.385783
# 1              2   92.490122      70.615520      23.443591  138.652426
# 2              1   88.141469      63.262618      23.404364  149.358082
# 3              2  108.453101      67.793632      20.751580  108.751638
# 4              1  127.849443      94.725685      22.603078   25.269987
# ..           ...         ...            ...            ...         ...
# 995            1  103.496355      41.059401      24.930299   43.675978
# 996            1   60.714150      64.082842      24.689064  111.562745
# 997            0   97.597727      64.122312      22.140339  108.138552
# 998            0   66.775137      55.908797      24.885274  219.521484
# 999            0   87.647268      69.111593      25.621266  134.335745
#
#            BMI  DiabetesPedigreeFunction        Age  Diagnosis
# ...

# %%
sns.scatterplot(x=diabetes['BMI'], y=diabetes['Glucose'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.relplot(data=diabetes, x='BMI', y = 'Glucose', hue = 'Pregnancies')

# %%
sns.relplot(data=diabetes, x='BMI', y = 'Glucose', hue = 'Pregnancies', size = 'Pregnancies')

# %%
sns.relplot(data=diabetes, x='BMI', y = 'Glucose', hue = 'Pregnancies', size = 'Pregnancies', sizes = (10,50))

# %%
sns.relplot(data=diabetes, x='BMI', y = 'Glucose', hue = 'Pregnancies', size = 'Pregnancies', sizes = (10,50))
plt.xlim(18,37)
plt.ylim(50,140)
plt.show()

# %% [markdown]
# ### **Group 1 Individual Challenge**

# %% [markdown]
# #### **Graphing Age and Insulin**

# %%
sns.scatterplot(x=diabetes['Age'], y=diabetes['Insulin'])
plt.show()

# %% [markdown]
# #### **Adjusting marker hue and size by the number of pregnancies; setting the markers to be semi-transparent**

# %%
sns.relplot(data=diabetes, x='Age', y = 'Insulin', hue = 'Pregnancies', size = 'Pregnancies', alpha = .5, sizes = (10,100))
plt.show()

# %% [markdown]
# #### **Explain how different relplot methods can be used to understand relationships**

# %% [markdown]
# Relplot allows the assignment of a series of facets and styles to several variables at once, letting analysts examine a dataset's complex characteristics in one plot. Relplot makes it easy to visualize both continuous and categorical data, and combinations of the two.
#
# The scatterplot default is useful when examining relationships between two variables where seeing individual observations is informative. The line plot works well when one of the variables represents time or another continuous variable like that. The ability to display two or more axes next to each other by the levels of a categorical variable makes it easy to compare the relationship between two or more variables as a function of another variable.

# %% [markdown]
# ### **Group 2 Demo**

# %%
sns.set(style = "whitegrid")

# %%
Salary_data = pd.read_csv("Salary_Data.csv")

# %%
Salary_data
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
sns.scatterplot(x = "Age", y = "Salary", data = Salary_data)
plt.show()

# %%
sns.scatterplot(x = "Age", \
                y = "Salary", \
                data = Salary_data)
plt.title("Default Scatterplot: Age vs. Salary")
plt.show()

# %%
plt.figure
sns.scatterplot(x = "Age", y = "Salary", hue = "Education Level", style = "Gender", data = Salary_data)
plt.title("Scatterplot: Age vs. Salary by Education Level and Gender")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

plt.figure
sns.scatterplot(x = "Age", \
                y = "Salary", \
                hue = "Education Level", \
                style = "Gender", \
                data = Salary_data, \
                palette = education_colors)
plt.title("Scatterplot: Age vs. Salary by Education Level and Gender")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

gender_markers = {"Female": "o", "Male": "s"}

plt.figure
sns.scatterplot(x = "Age", y = "Salary", hue = "Education Level", style = "Gender", data = Salary_data, palette = education_colors, markers = gender_markers)
plt.title("Scatterplot: Age vs. Salary by Education Level and Gender")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

gender_markers = {"Female": "o", "Male": "s"}

plt.figure
sns.set_style("ticks") #no gridlines
sns.scatterplot(x = "Age", y = "Salary", hue = "Education Level", style = "Gender", data = Salary_data, palette = education_colors, markers = gender_markers)
plt.title("Scatterplot: Age vs. Salary by Education Level and Gender")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

gender_markers = {"Female": "o", "Male": "s"}

plt.figure
sns.set_style("ticks") #no gridlines
sns.scatterplot(x = "Age", y = "Salary", hue = "Education Level", style = "Gender", data = Salary_data, palette = education_colors, markers = gender_markers)
plt.title("Scatterplot: Age vs. Salary by Education Level and Gender")
# Removing legend frame, changing its location
plt.legend(ncol=2, frameon=False, loc="lower right")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

gender_markers = {"Female": "o", "Male": "s"}

gender_colors = {"Female": "red", "Male": "blue"}

plt.figure
sns.set_style("ticks") #no gridlines
Bachelors = sns.scatterplot(x = "Age", y = "Salary", hue = "Gender", data = Salary_data[Salary_data["Education Level"] == "Bachelor's"], palette = gender_colors)
# Setting limits for x and y
Bachelors.set_xlim(25,50)
Bachelors.set_ylim(50000, 250000)

plt.title("Scatterplot: Age vs. Salary Based on Gender Among Bachelor's Degree Holders")
# Removing legend frame, changing its location
plt.legend(frameon=False, loc="upper left")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

gender_markers = {"Female": "o", "Male": "s"}

gender_colors = {"Female": "red", "Male": "blue"}

plt.figure
sns.set_style("ticks") #no gridlines
Bachelors = sns.scatterplot(x = "Age", y = "Salary", hue = "Gender", data = Salary_data[Salary_data["Education Level"] == "Master's"], palette = gender_colors)
# Setting limits for x and y
Bachelors.set_xlim(25,50)
Bachelors.set_ylim(50000, 250000)

plt.title("Scatterplot: Age vs. Salary Based on Gender Among Master's Degree Holders")
# Removing legend frame, changing its location
plt.legend(frameon=False, loc="upper left")
plt.show()

# %%
education_colors = {"Bachelor's": "green", "Master's": "blue", "PhD": "red"}

gender_markers = {"Female": "o", "Male": "s"}

gender_colors = {"Female": "red", "Male": "blue"}

plt.figure
sns.set_style("ticks") #no gridlines
Bachelors = sns.scatterplot(x = "Age", \
                            y = "Salary", \
                            hue = "Gender", \
                            data = Salary_data[Salary_data["Education Level"] == "PhD"], \
                            palette = gender_colors)
# Setting limits for x and y
Bachelors.set_xlim(25,50)
Bachelors.set_ylim(50000, 250000)

plt.title("Scatterplot: Age vs. Salary Based on Gender Among Doctoral Degree Holders")
# Removing legend frame, changing its location
plt.legend(frameon=False, loc="upper left")
plt.show()

# %%
sns.barplot(x = "Years of Experience", \
            y = "Education Level", \
            hue = "Gender", \
            data = Salary_data)
plt.show()

# %%
sns.barplot(x = "Education Level", \
            y = "Years of Experience", \
            hue = "Gender", \
            capsize = 0.1, \
            data = Salary_data)
plt.show()

# %%
sns.barplot(x = "Education Level", \
            y = "Years of Experience", \
            hue = "Gender", \
            capsize = 0.1, \
            errorbar=None, \
            data = Salary_data)
plt.show()

# %%
sns.barplot(x = "Education Level", \
            y = "Years of Experience", \
            hue = "Gender", \
            capsize = 0.1, \
            errorbar=None, \
            palette="dark:blue", \
            data = Salary_data)
plt.show()

# %%
sns.barplot(x = "Education Level", \
            y = "Years of Experience", \
            hue = "Gender", \
            capsize = 0.1, \
            errorbar=None, \
            palette="dark:blue", \
            hue_order=["Female","Male"], \
            data = Salary_data)
plt.show()

# %% [markdown]
# ### **Group 2 Individual Challenge**

# %% [markdown]
# #### **Exploring other Seaborn plot types**

# %% [markdown]
# ***Violin plot***

# %%
sns.violinplot(x = "Education Level", \
               y = "Salary", \
               hue = "Gender", \
               split = True, \
               gap = 0.1, \
               palette = "Set3", \
               linewidth = 0.8, \
               data = Salary_data)
sns.despine() 
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Gender', frameon=False)

plt.show()

# %% [markdown]
# ***Regression plot***

# %%
sns.regplot(x = "Age", \
            y = "Salary", \
            ci = 95, \
            data = Salary_data)

plt.show()

# %% [markdown]
# ***Separate regression plots for females and males***

# %%
from matplotlib import ticker as tkr

# %%
# Setting up the two axes
fig1, ax1 = plt.subplots(1, 2, figsize = (10,5))
fig1.tight_layout(pad = 4.0)
ax1[0].set_title("Females")
ax1[1].set_title("Males")

# Filtering data by gender
male = Salary_data.loc[Salary_data['Gender'] == 'Male']
female = Salary_data.loc[Salary_data['Gender'] == 'Female']

fem_plot = sns.regplot(ax = ax1[0], \
                       x = "Age", \
                       y = "Salary", \
                       ci = 95, \
                       data = female)
male_plot = sns.regplot(ax = ax1[1], \
                        x = "Age", \
                        y = "Salary", \
                        ci = 95, \
                        data = male)

# Setting the axes to be equal
fem_plot.set_xlim(20, 55)
male_plot.set_xlim(20, 55)

fem_plot.set_ylim(0, 275000)
male_plot.set_ylim(0, 275000)

# Formatting y-axis tik marks (Source: https://napsterinblue.github.io/notes/python/viz/tick_string_formatting/)
def thousands(x, pos):
    return '${:,.0f}K'.format(x*1e-3)
fmtr = tkr.FuncFormatter(thousands)

fem_plot.yaxis.set_major_formatter(fmtr)
male_plot.yaxis.set_major_formatter(fmtr)

plt.show()

# %% [markdown]
# ***Alaternate way of doing something like this with relplot***

# %%
sns.relplot(x = "Age", \
            y = "Salary", \
            col = "Gender", \
            data = Salary_data)
plt.show()
